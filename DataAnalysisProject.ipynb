# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumaroff/Angular-E-commerce-website/blob/master/DataAnalysisProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('Daily_Power_Gen_States_march_23.csv')

# %%
df.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 0                                 1.0              1.2  2015-01-01
# 1                                 0.0              4.8  2015-01-01
# 2                                 0.0              7.3  2015-01-01
# 3                                57.0            315.0  2015-01-01
# 4                                 0.0            109.8  2015-01-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126699 entries, 0 to 126698
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Region                              126699 non-null  object
#  1   States                              126699 non-null  object
#  2   Max.Demand Met during the day(MW)   126699 non-null  int64
#  3   Shortage during maximum Demand(MW)  126680 non-null  float64
#  4   Energy Met (MU)                     126698 non-null  float64
#  5   date                                126699 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.8+ MB

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126679 entries, 0 to 126698
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Region                              126679 non-null  object
#  1   States                              126679 non-null  object
#  2   Max.Demand Met during the day(MW)   126679 non-null  int64
#  3   Shortage during maximum Demand(MW)  126679 non-null  float64
#  4   Energy Met (MU)                     126679 non-null  float64
#  5   date                                126679 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 6.8+ MB

# %%
df['Region'].unique()
# Out:
# array(['NER', 'WR', 'NR', 'SR', 'ER'], dtype=object)

# %%
South_Region = df[df['Region']=='SR']

# %%
# South_Region['States'].unique()
South_Region['States'].replace({'Pondy':'Puducherry'},inplace=True)
# Out:
# <ipython-input-69-7528b7004f96>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   South_Region['States'].replace({'Pondy':'Puducherry'},inplace=True)

# %%
South_Region.head()
# Out:
#    Region          States  Max.Demand Met during the day(MW)  \
# 18     SR  Andhra Pradesh                               5963
# 29     SR      Puducherry                                278
# 30     SR      Tamil Nadu                              10621
# 31     SR          Kerala                               3288
# 32     SR       Karnataka                               7914
#
#     Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 18                                 0.0            131.5  2015-01-01
# 29                                 0.0              5.4  2015-01-01
# 30                               891.0            235.5  2015-01-01
# 31                               125.0             60.9  2015-01-01
# 32                               300.0            166.1  2015-01-01

# %%
South_Region = South_Region.reset_index()

# %%
South_Region = South_Region.iloc[:,1:]

# %%
South_Region.head()
# Out:
#   Region          States  Max.Demand Met during the day(MW)  \
# 0     SR  Andhra Pradesh                               5963
# 1     SR      Puducherry                                278
# 2     SR      Tamil Nadu                              10621
# 3     SR          Kerala                               3288
# 4     SR       Karnataka                               7914
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 0                                 0.0            131.5  2015-01-01
# 1                                 0.0              5.4  2015-01-01
# 2                               891.0            235.5  2015-01-01
# 3                               125.0             60.9  2015-01-01
# 4                               300.0            166.1  2015-01-01

# %%
North_Region = df[df['Region']=='NR']
North_Region = North_Region.reset_index()
North_Region = North_Region.iloc[:,1:]

# %%
North_Region.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0     NR   Chandigarh                                224
# 1     NR           HP                               1367
# 2     NR  Uttarakhand                               1768
# 3     NR           UP                               9998
# 4     NR        Delhi                               4009
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 0                                 0.0              3.8  2015-01-01
# 1                                 0.0             25.1  2015-01-01
# 2                                 0.0             33.9  2015-01-01
# 3                              3645.0            244.0  2015-01-01
# 4                                 0.0             67.6  2015-01-01

# %%
South_Region[South_Region['States']=='Tamil Nadu']
# Out:
#       Region      States  Max.Demand Met during the day(MW)  \
# 2         SR  Tamil Nadu                              10621
# 7         SR  Tamil Nadu                              12352
# 15        SR  Tamil Nadu                              11924
# 20        SR  Tamil Nadu                              12719
# 26        SR  Tamil Nadu                              13140
# ...      ...         ...                                ...
# 20775     SR  Tamil Nadu                              13631
# 20781     SR  Tamil Nadu                              13703
# 20788     SR  Tamil Nadu                              12899
# 20797     SR  Tamil Nadu                              13145
# 20800     SR  Tamil Nadu                              14738
#
#        Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 2                                   891.0            235.5  2015-01-01
# 7                                     0.0            257.1  2016-01-01
# ...

# %%
# TamilNadu = South_Region[South_Region['States']=='Tamil Nadu']

# %%
# val = South_Region['Energy Met (MU)']
# val.iloc[:10,:]
# lab = South_Region['States'].iloc[:1000,:]
# plt.pie(South_Region['Energy Met (MU)'].iloc[:1000,:],labels=South_Region['States'].iloc[:1000,:],autopct='%0.0f%%')

# %%
plt.figure(figsize=(10,5))
val = sns.countplot(x=South_Region['States'],hue=South_Region['States'])
for i in val.containers:
  val.bar_label(i)

# %%
plt.figure(figsize=(10,5))
val1 = sns.barplot(x='States',y='Energy Met (MU)',data = South_Region)
for i in val1.containers:
  val1.bar_label(i)

# %%
South_Region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20804 entries, 0 to 20803
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Region                              20804 non-null  object
#  1   States                              20804 non-null  object
#  2   Max.Demand Met during the day(MW)   20804 non-null  int64
#  3   Shortage during maximum Demand(MW)  20804 non-null  float64
#  4   Energy Met (MU)                     20804 non-null  float64
#  5   date                                20804 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 975.3+ KB

# %%
South_Region['date']=pd.to_datetime(South_Region['date'])
# year = [i.year for i in South_Region['date']]
South_Region['year']=[i.year for i in South_Region['date']]

# %%
# South_Region.info()
plt.figure(figsize=(10,5))
plt.title('South Region Total power generated by year in Million Units')
val2 = sns.barplot(x='year',y='Energy Met (MU)',data=South_Region,hue='year')
for i in val2.containers:
  val2.bar_label(i)

# %%
# Tamil Nadu
TamilNadu = South_Region[South_Region['States']=='Tamil Nadu']
TamilNadu
plt.figure(figsize=(10,5))
plt.title('Tamil Nadu Total power generated by year in Million Units')
val3 = sns.barplot(x='year',y='Energy Met (MU)',data=TamilNadu,hue='year')
for i in val3.containers:
  val3.bar_label(i)

# %%
# South_Region['States'].unique()
# South_Region= South_Region.iloc[:200,:]
# plt.pie(South_Region['Energy Met (MU)'],labels=South_Region['States'])

# %%
North_Region['States'].unique()
# Out:
# array(['Chandigarh', 'HP', 'Uttarakhand', 'UP', 'Delhi', 'Rajasthan',
#        'Haryana', 'J&K', 'Punjab', 'J&K(UT) and Ladakh(UT)',
#        'J&K(UT) & Ladakh(UT)', 'J&K(UT) & \nLadakh(UT)', 'J&K(UT) &',
#        'Railways_NR ISTS'], dtype=object)

# %%
West_Region = df[df['Region']=='WR']
West_Region = West_Region.reset_index()
West_Region = West_Region.iloc[:,1:]

# %%
West_Region['States'].unique()
West_Region['date'] = pd.to_datetime(West_Region['date'])
year = [i.year for i in West_Region['date']]

West_Region['year']=year

# %%
Goa = West_Region[West_Region['States']=='Goa']
Goa.head()
# Out:
#    Region States  Max.Demand Met during the day(MW)  \
# 1      WR    Goa                                383
# 12     WR    Goa                                377
# 23     WR    Goa                                392
# 26     WR    Goa                                421
# 32     WR    Goa                                462
#
#     Shortage during maximum Demand(MW)  Energy Met (MU)       date  year
# 1                                  0.0              7.3 2015-01-01  2015
# 12                                 0.0              7.6 2016-01-01  2016
# 23                                 0.0              7.8 2016-01-01  2016
# 26                                 0.0              9.2 2018-01-01  2018
# 32                                 0.0              9.0 2019-01-01  2019

# %%
plt.figure(figsize=(10,5))
plt.title('Goa Total power generated by year in Million Units')
val3 = sns.barplot(x='year',y='Energy Met (MU)',data=Goa,hue='year')
for i in val3.containers:
  val3.bar_label(i)

# %%
plt.figure(figsize=(10,5))
plt.title('West Region Total power generated by year in Million Units')
val3 = sns.barplot(x='States',y='Energy Met (MU)',data=West_Region,hue='States')
for i in val3.containers:
  val3.bar_label(i)
